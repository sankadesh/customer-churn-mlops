# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: pandas in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (2.3.1)
# Requirement already satisfied: scikit-learn in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.7.0)
# Requirement already satisfied: openai in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.95.1)
# Requirement already satisfied: groq in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.30.0)
# Requirement already satisfied: seaborn in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: dotenv in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (0.9.9)
# Requirement already satisfied: matplotlib in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (3.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (2.11.7)
# Requirement already satisfied: sniffio in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from openai->-r requirements.txt (line 4)) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: certifi in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 4)) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 4)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: python-dotenv in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from dotenv->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 8)) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 8)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 8)) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 8)) (3.2.3)
# Requirement already satisfied: six>=1.5 in /Users/1zuu/miniforge3/envs/bprmls/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)

# %% [markdown]
# ### 1. Import Dependencies

# %%
import os
import numpy as np
import pandas as pd # alias
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. basic processing

# %%
df = pd.read_csv()
df.head(5)'data/processed/ChurnModelling_Missing_Values_Handled.csv'
# Out:
#    CreditScore Geography  Gender    Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.00       2       0.00              1
# 1          608     Spain  Female  41.00       1   83807.86              1
# 2          502    France  Female  42.00       8  159660.80              3
# 3          699    France  Female  38.91       1       0.00              2
# 4          850     Spain  Female  43.00       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
print(f"No of Rows : {len(df)}")
# Out:
# No of Rows : 10000

# %% [markdown]
# ### 3. outlier detection techniques

# %% [markdown]
# #### 3.1 distribution plots

# %%
categorical_columns = [
                       'Geography',
                       'Gender', 'HasCrCard',
                       'IsActiveMember', 'Exited'
                        ]

numerical_columns = [
                    'Age', 'Tenure', 'CreditScore',
                    'Balance', 'EstimatedSalary', 'NumOfProducts'
                    ]

# %%
fig, axes = plt.subplots(2, 3, figsize=(10, 8))
axes = axes.flatten()

for idx, col in enumerate(numerical_columns):
    sns.kdeplot(
                data=df[col],
                ax=axes[idx]
                )
    axes[idx].set_title(col)
    axes[idx].set_xlabel('')

plt.show()

# %%
fig, axes = plt.subplots(1, 5, figsize=(10, 8))

for idx, col in enumerate(categorical_columns):
    df[col].value_counts().plot(
                                kind='pie',
                                ax=axes[idx]
                                )
    axes[idx].set_title(col)
    axes[idx].set_ylabel('')

plt.show()

# %% [markdown]
# #### 3.2 box plots

# %%
numerical_columns = [
                    'Age', 'Tenure', 'CreditScore',
                    'Balance', 'EstimatedSalary', 'NumOfProducts'
                    ]

fig, axes = plt.subplots(2, 3, figsize=(15, 8))

sns.boxplot(data=df['CreditScore'], ax=axes[0,0])
sns.boxplot(data=df['Tenure'], ax=axes[0,1])
sns.boxplot(data=df['Age'], ax=axes[0,2])
sns.boxplot(data=df['Balance'], ax=axes[1,0])
sns.boxplot(data=df['EstimatedSalary'], ax=axes[1,1])
sns.boxplot(data=df['NumOfProducts'], ax=axes[1,2])

plt.show()

# %% [markdown]
# #### 3.3 empirical rule / 3-sigma rule

# %%
def find_anomaly(data):

    mean = data.mean()
    std = data.std()

    upper_bound = mean + (3 * std)
    lower_bound = mean - (3 * std)

    return (data > upper_bound) | (data < lower_bound)

# %%
numerical_columns = [
                    'Age', 'Tenure', 'CreditScore',
                    'Balance', 'EstimatedSalary'
                    ]

for col in numerical_columns:
    n_outliers = find_anomaly(df[col]).sum()
    n_outlier_percentage = round(n_outliers / len(df), 3)
    print(f"{col} : {n_outliers} outliers ({n_outlier_percentage} %)")
# Out:
# Age : 144 outliers (0.014 %)
# Tenure : 0 outliers (0.0 %)
# CreditScore : 8 outliers (0.001 %)
# Balance : 0 outliers (0.0 %)
# EstimatedSalary : 0 outliers (0.0 %)

# %% [markdown]
# #### 3.4 IQR Method

# %%
def find_anomaly(data):
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)

    IQR = Q3 - Q1 

    upper_bound = Q3 + 1.5 * IQR
    lower_bound = Q1 - 1.5 * IQR 

    return (data > upper_bound) | (data < lower_bound)

# %%
numerical_columns = [
                    'Age', 'Tenure', 'CreditScore',
                    'Balance', 'EstimatedSalary'
                    ]

for col in numerical_columns:
    n_outliers = find_anomaly(df[col]).sum()
    n_outlier_percentage = round(n_outliers / len(df), 3)
    print(f"{col} : {n_outliers} outliers ({n_outlier_percentage} %)")
# Out:
# Age : 501 outliers (0.05 %)
# Tenure : 0 outliers (0.0 %)
# CreditScore : 15 outliers (0.002 %)
# Balance : 0 outliers (0.0 %)
# EstimatedSalary : 0 outliers (0.0 %)

# %%
outlier_mask_log = pd.DataFrame()
for col in numerical_columns:
    outlier_mask_log[col] = find_anomaly(df[col])

outlier_count = outlier_mask_log.sum(axis=1)
outlier_mask_log['Outlier Count'] = outlier_count
outlier_mask_log = outlier_mask_log[outlier_mask_log['Outlier Count'] == 2]
outlier_mask_log
# Out:
#        Age  Tenure  CreditScore  Balance  EstimatedSalary  Outlier Count
# 8762  True   False         True    False            False              2

# %%
df.to_csv('data/processed/ChurnModelling_Outliers_Handled.csv', index=False)
